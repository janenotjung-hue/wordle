# %%
import gymnasium as gym
from imitation.algorithms.adversarial.gail import GAIL
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from imitation.rewards.reward_nets import BasicRewardNet
from stable_baselines3 import PPO
from stable_baselines3.a2c import MlpPolicy
from imitation.data import rollout
import numpy as np
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common import monitor
from Wordle import WordleEnv
import os

env = monitor.Monitor(WordleEnv())
venv = DummyVecEnv([lambda: RolloutInfoWrapper(env)])  # Wrap a single environment -- only useful for simple testing like this
venv.render_mode="human"

#rollouts = trajectories
rollouts = np.load('data/trajectories_all.npy', allow_pickle=True)

transitions = rollout.flatten_trajectories_with_rew(rollouts)

# %%
#discriminator
learner = PPO(
    env=env,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0004,
    gamma=0.95,
    n_epochs=5,
    seed=None,
)

#generator
reward_net = BasicRewardNet(
    observation_space=env.observation_space,
    action_space=env.action_space,
    normalize_input_layer=RunningNorm,
)

#GAIL
gail_trainer = GAIL(
    demonstrations=transitions,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
    allow_variable_horizon=True
)
# Out:
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html for more information.

# %%
# evaluate the learner before training
learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True,
)

# %%
# train the learner and evaluate again
gail_trainer.train(100000)  # Train for 800_000 steps to match expert.
learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True,
)
# Out:
# round:   0%|          | 0/48 [00:00<?, ?it/s]
# ------------------------------------------
# | raw/                        |          |
# |    gen/rollout/ep_len_mean  | 6        |
# |    gen/rollout/ep_rew_mean  | -8.25    |
# |    gen/time/fps             | 72       |
# |    gen/time/iterations      | 1        |
# |    gen/time/time_elapsed    | 28       |
# |    gen/time/total_timesteps | 2048     |
# ------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.499    |
# |    disc/disc_acc_expert             | 0.998    |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.692    |
# |    disc/disc_loss                   | 0.695    |
# |    disc/disc_proportion_expert_pred | 0.999    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.508    |
# |    disc/disc_acc_expert             | 0.994    |
# |    disc/disc_acc_gen                | 0.0225   |
# |    disc/disc_entropy                | 0.692    |
# |    disc/disc_loss                   | 0.685    |
# |    disc/disc_proportion_expert_pred | 0.986    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.58     |
# |    disc/disc_acc_expert             | 0.983    |
# |    disc/disc_acc_gen                | 0.177    |
# |    disc/disc_entropy                | 0.692    |
# |    disc/disc_loss                   | 0.675    |
# |    disc/disc_proportion_expert_pred | 0.903    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.681    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.383    |
# |    disc/disc_entropy                | 0.692    |
# |    disc/disc_loss                   | 0.665    |
# |    disc/disc_proportion_expert_pred | 0.798    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.76     |
# |    disc/disc_acc_expert             | 0.955    |
# |    disc/disc_acc_gen                | 0.565    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.657    |
# |    disc/disc_proportion_expert_pred | 0.695    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.807    |
# |    disc/disc_acc_expert             | 0.955    |
# |    disc/disc_acc_gen                | 0.659    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0.648    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.861    |
# |    disc/disc_acc_expert             | 0.946    |
# |    disc/disc_acc_gen                | 0.776    |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.638    |
# |    disc/disc_proportion_expert_pred | 0.585    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.904    |
# |    disc/disc_acc_expert             | 0.986    |
# |    disc/disc_acc_gen                | 0.822    |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.622    |
# |    disc/disc_proportion_expert_pred | 0.582    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.7      |
# |    disc/disc_acc_expert             | 0.975    |
# |    disc/disc_acc_gen                | 0.426    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.66     |
# |    disc/disc_proportion_expert_pred | 0.775    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 6        |
# |    gen/rollout/ep_rew_mean          | -8.25    |
# |    gen/time/fps                     | 72       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 28       |
# |    gen/time/total_timesteps         | 2.05e+03 |
# |    gen/train/approx_kl              | 0.0438   |
# |    gen/train/clip_fraction          | 0.492    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -9.47    |
# |    gen/train/explained_variance     | 0.0228   |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.131   |
# |    gen/train/n_updates              | 5        |
# |    gen/train/policy_gradient_loss   | -0.113   |
# |    gen/train/value_loss             | 0.383    |
# --------------------------------------------------
# round:   2%|▏         | 1/48 [00:37<29:16, 37.37s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 6          |
# |    gen/rollout/ep_rew_mean         | -8.12      |
# |    gen/rollout/ep_rew_wrapped_mean | 4.38       |
# |    gen/time/fps                    | 71         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 28         |
# |    gen/time/total_timesteps        | 4096       |
# |    gen/train/approx_kl             | 0.04380278 |
# |    gen/train/clip_fraction         | 0.492      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -9.47      |
# |    gen/train/explained_variance    | 0.0228     |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | -0.131     |
# |    gen/train/n_updates             | 5          |
# |    gen/train/policy_gradient_loss  | -0.113     |
# |    gen/train/value_loss            | 0.383      |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.658    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.337    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0.821    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.719    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.459    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.634    |
# |    disc/disc_proportion_expert_pred | 0.76     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.766    |
# |    disc/disc_acc_expert             | 0.978    |
# |    disc/disc_acc_gen                | 0.554    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.623    |
# |    disc/disc_proportion_expert_pred | 0.712    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.776    |
# |    disc/disc_acc_expert             | 0.983    |
# |    disc/disc_acc_gen                | 0.568    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.612    |
# |    disc/disc_proportion_expert_pred | 0.708    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.819    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.659    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.598    |
# |    disc/disc_proportion_expert_pred | 0.66     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.847    |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.718    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.583    |
# |    disc/disc_proportion_expert_pred | 0.629    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.859    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.738    |
# |    disc/disc_entropy                | 0.677    |
# |    disc/disc_loss                   | 0.571    |
# |    disc/disc_proportion_expert_pred | 0.621    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.88     |
# |    disc/disc_acc_expert             | 0.984    |
# |    disc/disc_acc_gen                | 0.775    |
# |    disc/disc_entropy                | 0.674    |
# |    disc/disc_loss                   | 0.557    |
# |    disc/disc_proportion_expert_pred | 0.604    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.79     |
# |    disc/disc_acc_expert             | 0.98     |
# |    disc/disc_acc_gen                | 0.601    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.603    |
# |    disc/disc_proportion_expert_pred | 0.689    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 6        |
# |    gen/rollout/ep_rew_mean          | -8.12    |
# |    gen/rollout/ep_rew_wrapped_mean  | 4.38     |
# |    gen/time/fps                     | 71       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 28       |
# |    gen/time/total_timesteps         | 4.1e+03  |
# |    gen/train/approx_kl              | 0.0504   |
# |    gen/train/clip_fraction          | 0.665    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -9.46    |
# |    gen/train/explained_variance     | 0.875    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.0802  |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.118   |
# |    gen/train/value_loss             | 0.112    |
# --------------------------------------------------
# round:   4%|▍         | 2/48 [01:15<28:46, 37.53s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 6           |
# |    gen/rollout/ep_rew_mean         | -8.17       |
# |    gen/rollout/ep_rew_wrapped_mean | 4.47        |
# |    gen/time/fps                    | 67          |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 30          |
# |    gen/time/total_timesteps        | 6144        |
# |    gen/train/approx_kl             | 0.050360154 |
# |    gen/train/clip_fraction         | 0.665       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -9.46       |
# |    gen/train/explained_variance    | 0.875       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.0802     |
# |    gen/train/n_updates             | 10          |
# |    gen/train/policy_gradient_loss  | -0.118      |
# |    gen/train/value_loss            | 0.112       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.752    |
# |    disc/disc_acc_expert             | 0.98     |
# |    disc/disc_acc_gen                | 0.523    |
# |    disc/disc_entropy                | 0.67     |
# |    disc/disc_loss                   | 0.582    |
# |    disc/disc_proportion_expert_pred | 0.729    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.78     |
# |    disc/disc_acc_expert             | 0.984    |
# |    disc/disc_acc_gen                | 0.576    |
# |    disc/disc_entropy                | 0.667    |
# |    disc/disc_loss                   | 0.564    |
# |    disc/disc_proportion_expert_pred | 0.704    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.807    |
# |    disc/disc_acc_expert             | 0.977    |
# |    disc/disc_acc_gen                | 0.637    |
# |    disc/disc_entropy                | 0.662    |
# |    disc/disc_loss                   | 0.544    |
# |    disc/disc_proportion_expert_pred | 0.67     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.822    |
# |    disc/disc_acc_expert             | 0.967    |
# |    disc/disc_acc_gen                | 0.678    |
# |    disc/disc_entropy                | 0.659    |
# |    disc/disc_loss                   | 0.53     |
# |    disc/disc_proportion_expert_pred | 0.645    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.865    |
# |    disc/disc_acc_expert             | 0.97     |
# |    disc/disc_acc_gen                | 0.76     |
# |    disc/disc_entropy                | 0.653    |
# |    disc/disc_loss                   | 0.506    |
# |    disc/disc_proportion_expert_pred | 0.605    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.876    |
# |    disc/disc_acc_expert             | 0.981    |
# |    disc/disc_acc_gen                | 0.771    |
# |    disc/disc_entropy                | 0.646    |
# |    disc/disc_loss                   | 0.488    |
# |    disc/disc_proportion_expert_pred | 0.605    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.886    |
# |    disc/disc_acc_expert             | 0.969    |
# |    disc/disc_acc_gen                | 0.804    |
# |    disc/disc_entropy                | 0.638    |
# |    disc/disc_loss                   | 0.468    |
# |    disc/disc_proportion_expert_pred | 0.583    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.899    |
# |    disc/disc_acc_expert             | 0.973    |
# |    disc/disc_acc_gen                | 0.826    |
# |    disc/disc_entropy                | 0.63     |
# |    disc/disc_loss                   | 0.45     |
# |    disc/disc_proportion_expert_pred | 0.573    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.836    |
# |    disc/disc_acc_expert             | 0.975    |
# |    disc/disc_acc_gen                | 0.697    |
# |    disc/disc_entropy                | 0.653    |
# |    disc/disc_loss                   | 0.517    |
# |    disc/disc_proportion_expert_pred | 0.639    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 6        |
# |    gen/rollout/ep_rew_mean          | -8.17    |
# |    gen/rollout/ep_rew_wrapped_mean  | 4.47     |
# |    gen/time/fps                     | 67       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 30       |
# |    gen/time/total_timesteps         | 6.14e+03 |
# |    gen/train/approx_kl              | 0.0557   |
# |    gen/train/clip_fraction          | 0.705    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -9.46    |
# |    gen/train/explained_variance     | 0.895    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.105   |
# |    gen/train/n_updates              | 15       |
# |    gen/train/policy_gradient_loss   | -0.121   |
# |    gen/train/value_loss             | 0.122    |
# --------------------------------------------------
# round:   6%|▋         | 3/48 [01:54<28:45, 38.35s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 6          |
# |    gen/rollout/ep_rew_mean         | -8.31      |
# |    gen/rollout/ep_rew_wrapped_mean | 4.31       |
# |    gen/time/fps                    | 66         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 30         |
# |    gen/time/total_timesteps        | 8192       |
# |    gen/train/approx_kl             | 0.05569288 |
# |    gen/train/clip_fraction         | 0.705      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -9.46      |
# |    gen/train/explained_variance    | 0.895      |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | -0.105     |
# |    gen/train/n_updates             | 15         |
# |    gen/train/policy_gradient_loss  | -0.121     |
# |    gen/train/value_loss            | 0.122      |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.812    |
# |    disc/disc_acc_expert             | 0.971    |
# |    disc/disc_acc_gen                | 0.654    |
# |    disc/disc_entropy                | 0.623    |
# |    disc/disc_loss                   | 0.497    |
# |    disc/disc_proportion_expert_pred | 0.658    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.838    |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.7      |
# |    disc/disc_entropy                | 0.611    |
# |    disc/disc_loss                   | 0.468    |
# |    disc/disc_proportion_expert_pred | 0.638    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.845    |
# |    disc/disc_acc_expert             | 0.973    |
# |    disc/disc_acc_gen                | 0.717    |
# |    disc/disc_entropy                | 0.604    |
# |    disc/disc_loss                   | 0.451    |
# |    disc/disc_proportion_expert_pred | 0.628    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.866    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.753    |
# |    disc/disc_entropy                | 0.592    |
# |    disc/disc_loss                   | 0.418    |
# |    disc/disc_proportion_expert_pred | 0.613    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.886    |
# |    disc/disc_acc_expert             | 0.975    |
# |    disc/disc_acc_gen                | 0.797    |
# |    disc/disc_entropy                | 0.58     |
# |    disc/disc_loss                   | 0.397    |
# |    disc/disc_proportion_expert_pred | 0.589    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.886    |
# |    disc/disc_acc_expert             | 0.975    |
# |    disc/disc_acc_gen                | 0.797    |
# |    disc/disc_entropy                | 0.563    |
# |    disc/disc_loss                   | 0.378    |
# |    disc/disc_proportion_expert_pred | 0.589    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.9      |
# |    disc/disc_acc_expert             | 0.966    |
# |    disc/disc_acc_gen                | 0.834    |
# |    disc/disc_entropy                | 0.549    |
# |    disc/disc_loss                   | 0.359    |
# |    disc/disc_proportion_expert_pred | 0.566    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.928    |
# |    disc/disc_acc_expert             | 0.973    |
# |    disc/disc_acc_gen                | 0.884    |
# |    disc/disc_entropy                | 0.533    |
# |    disc/disc_loss                   | 0.332    |
# |    disc/disc_proportion_expert_pred | 0.544    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.87     |
# |    disc/disc_acc_expert             | 0.973    |
# |    disc/disc_acc_gen                | 0.767    |
# |    disc/disc_entropy                | 0.582    |
# |    disc/disc_loss                   | 0.412    |
# |    disc/disc_proportion_expert_pred | 0.603    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 6        |
# |    gen/rollout/ep_rew_mean          | -8.31    |
# |    gen/rollout/ep_rew_wrapped_mean  | 4.31     |
# |    gen/time/fps                     | 66       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 30       |
# |    gen/time/total_timesteps         | 8.19e+03 |
# |    gen/train/approx_kl              | 0.0703   |
# |    gen/train/clip_fraction          | 0.708    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -9.45    |
# |    gen/train/explained_variance     | 0.848    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.0725  |
# |    gen/train/n_updates              | 20       |
# |    gen/train/policy_gradient_loss   | -0.121   |
# |    gen/train/value_loss             | 0.182    |
# --------------------------------------------------
# round:   8%|▊         | 4/48 [02:34<28:36, 39.02s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 6          |
# |    gen/rollout/ep_rew_mean         | -8.36      |
# |    gen/rollout/ep_rew_wrapped_mean | 3.9        |
# |    gen/time/fps                    | 57         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 35         |
# |    gen/time/total_timesteps        | 10240      |
# |    gen/train/approx_kl             | 0.07030367 |
# |    gen/train/clip_fraction         | 0.708      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -9.45      |
# |    gen/train/explained_variance    | 0.848      |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | -0.0725    |
# |    gen/train/n_updates             | 20         |
# |    gen/train/policy_gradient_loss  | -0.121     |
# |    gen/train/value_loss            | 0.182      |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.836    |
# |    disc/disc_acc_expert             | 0.974    |
# |    disc/disc_acc_gen                | 0.699    |
# |    disc/disc_entropy                | 0.537    |
# |    disc/disc_loss                   | 0.402    |
# |    disc/disc_proportion_expert_pred | 0.637    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.86     |
# |    disc/disc_acc_expert             | 0.967    |
# |    disc/disc_acc_gen                | 0.754    |
# |    disc/disc_entropy                | 0.524    |
# |    disc/disc_loss                   | 0.382    |
# |    disc/disc_proportion_expert_pred | 0.606    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.862    |
# |    disc/disc_acc_expert             | 0.96     |
# |    disc/disc_acc_gen                | 0.764    |
# |    disc/disc_entropy                | 0.512    |
# |    disc/disc_loss                   | 0.36     |
# |    disc/disc_proportion_expert_pred | 0.598    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.899    |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.822    |
# |    disc/disc_entropy                | 0.491    |
# |    disc/disc_loss                   | 0.323    |
# |    disc/disc_proportion_expert_pred | 0.577    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.915    |
# |    disc/disc_acc_expert             | 0.963    |
# |    disc/disc_acc_gen                | 0.866    |
# |    disc/disc_entropy                | 0.474    |
# |    disc/disc_loss                   | 0.292    |
# |    disc/disc_proportion_expert_pred | 0.548    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.92     |
# |    disc/disc_acc_expert             | 0.965    |
# |    disc/disc_acc_gen                | 0.876    |
# |    disc/disc_entropy                | 0.463    |
# |    disc/disc_loss                   | 0.295    |
# |    disc/disc_proportion_expert_pred | 0.544    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.94     |
# |    disc/disc_acc_expert             | 0.967    |
# |    disc/disc_acc_gen                | 0.913    |
# |    disc/disc_entropy                | 0.447    |
# |    disc/disc_loss                   | 0.268    |
# |    disc/disc_proportion_expert_pred | 0.527    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.941    |
# |    disc/disc_acc_expert             | 0.96     |
# |    disc/disc_acc_gen                | 0.923    |
# |    disc/disc_entropy                | 0.419    |
# |    disc/disc_loss                   | 0.243    |
# |    disc/disc_proportion_expert_pred | 0.519    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.897    |
# |    disc/disc_acc_expert             | 0.966    |
# |    disc/disc_acc_gen                | 0.827    |
# |    disc/disc_entropy                | 0.483    |
# |    disc/disc_loss                   | 0.321    |
# |    disc/disc_proportion_expert_pred | 0.57     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 6        |
# |    gen/rollout/ep_rew_mean          | -8.36    |
# |    gen/rollout/ep_rew_wrapped_mean  | 3.9      |
# |    gen/time/fps                     | 57       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 35       |
# |    gen/time/total_timesteps         | 1.02e+04 |
# |    gen/train/approx_kl              | 0.0771   |
# |    gen/train/clip_fraction          | 0.689    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -9.44    |
# |    gen/train/explained_variance     | 0.696    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0198   |
# |    gen/train/n_updates              | 25       |
# |    gen/train/policy_gradient_loss   | -0.113   |
# |    gen/train/value_loss             | 0.405    |
# --------------------------------------------------
# round:  10%|█         | 5/48 [03:21<29:57, 41.79s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 6          |
# |    gen/rollout/ep_rew_mean         | -8.43      |
# |    gen/rollout/ep_rew_wrapped_mean | 3.53       |
# |    gen/time/fps                    | 53         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 38         |
# |    gen/time/total_timesteps        | 12288      |
# |    gen/train/approx_kl             | 0.07712114 |
# |    gen/train/clip_fraction         | 0.689      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -9.44      |
# |    gen/train/explained_variance    | 0.696      |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | 0.0198     |
# |    gen/train/n_updates             | 25         |
# |    gen/train/policy_gradient_loss  | -0.113     |
# |    gen/train/value_loss            | 0.405      |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.866    |
# |    disc/disc_acc_expert             | 0.961    |
# |    disc/disc_acc_gen                | 0.771    |
# |    disc/disc_entropy                | 0.431    |
# |    disc/disc_loss                   | 0.338    |
# |    disc/disc_proportion_expert_pred | 0.595    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.876    |
# |    disc/disc_acc_expert             | 0.957    |
# |    disc/disc_acc_gen                | 0.795    |
# |    disc/disc_entropy                | 0.411    |
# |    disc/disc_loss                   | 0.308    |
# |    disc/disc_proportion_expert_pred | 0.581    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.913    |
# |    disc/disc_acc_expert             | 0.967    |
# |    disc/disc_acc_gen                | 0.858    |
# |    disc/disc_entropy                | 0.393    |
# |    disc/disc_loss                   | 0.266    |
# |    disc/disc_proportion_expert_pred | 0.554    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.917    |
# |    disc/disc_acc_expert             | 0.954    |
# |    disc/disc_acc_gen                | 0.881    |
# |    disc/disc_entropy                | 0.375    |
# |    disc/disc_loss                   | 0.248    |
# |    disc/disc_proportion_expert_pred | 0.537    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.94     |
# |    disc/disc_acc_expert             | 0.96     |
# |    disc/disc_acc_gen                | 0.92     |
# |    disc/disc_entropy                | 0.368    |
# |    disc/disc_loss                   | 0.223    |
# |    disc/disc_proportion_expert_pred | 0.52     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.939    |
# |    disc/disc_acc_expert             | 0.961    |
# |    disc/disc_acc_gen                | 0.917    |
# |    disc/disc_entropy                | 0.349    |
# |    disc/disc_loss                   | 0.217    |
# |    disc/disc_proportion_expert_pred | 0.522    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.95     |
# |    disc/disc_acc_expert             | 0.962    |
# |    disc/disc_acc_gen                | 0.938    |
# |    disc/disc_entropy                | 0.329    |
# |    disc/disc_loss                   | 0.195    |
# |    disc/disc_proportion_expert_pred | 0.512    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.946    |
# |    disc/disc_acc_expert             | 0.957    |
# |    disc/disc_acc_gen                | 0.935    |
# |    disc/disc_entropy                | 0.309    |
# |    disc/disc_loss                   | 0.188    |
# |    disc/disc_proportion_expert_pred | 0.511    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.918    |
# |    disc/disc_acc_expert             | 0.96     |
# |    disc/disc_acc_gen                | 0.877    |
# |    disc/disc_entropy                | 0.371    |
# |    disc/disc_loss                   | 0.248    |
# |    disc/disc_proportion_expert_pred | 0.542    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 6        |
# |    gen/rollout/ep_rew_mean          | -8.43    |
# |    gen/rollout/ep_rew_wrapped_mean  | 3.53     |
# |    gen/time/fps                     | 53       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 38       |
# |    gen/time/total_timesteps         | 1.23e+04 |
# |    gen/train/approx_kl              | 0.0867   |
# |    gen/train/clip_fraction          | 0.696    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -9.43    |
# |    gen/train/explained_variance     | 0.56     |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.176    |
# |    gen/train/n_updates              | 30       |
# |    gen/train/policy_gradient_loss   | -0.113   |
# |    gen/train/value_loss             | 0.599    |
# --------------------------------------------------
# round:  12%|█▎        | 6/48 [04:12<31:29, 44.99s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 6          |
# |    gen/rollout/ep_rew_mean         | -8.41      |
# |    gen/rollout/ep_rew_wrapped_mean | 2.95       |
# |    gen/time/fps                    | 55         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 36         |
# |    gen/time/total_timesteps        | 14336      |
# |    gen/train/approx_kl             | 0.08671473 |
# |    gen/train/clip_fraction         | 0.696      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -9.43      |
# |    gen/train/explained_variance    | 0.56       |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | 0.176      |
# |    gen/train/n_updates             | 30         |
# |    gen/train/policy_gradient_loss  | -0.113     |
# |    gen/train/value_loss            | 0.599      |
# ---------------------------------------------------
# ...
# round:  96%|█████████▌| 46/48 [31:10<01:24, 42.27s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 5.96        |
# |    gen/rollout/ep_rew_mean         | -7.07       |
# |    gen/rollout/ep_rew_wrapped_mean | 1.83        |
# |    gen/time/fps                    | 62          |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 32          |
# |    gen/time/total_timesteps        | 96256       |
# |    gen/train/approx_kl             | 0.042109817 |
# |    gen/train/clip_fraction         | 0.182       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -2.89       |
# |    gen/train/explained_variance    | 0.133       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.626       |
# |    gen/train/n_updates             | 230         |
# |    gen/train/policy_gradient_loss  | -0.0322     |
# |    gen/train/value_loss            | 0.977       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.88     |
# |    disc/disc_acc_expert             | 0.973    |
# |    disc/disc_acc_gen                | 0.787    |
# |    disc/disc_entropy                | 0.269    |
# |    disc/disc_loss                   | 0.267    |
# |    disc/disc_proportion_expert_pred | 0.593    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.891    |
# |    disc/disc_acc_expert             | 0.971    |
# |    disc/disc_acc_gen                | 0.811    |
# |    disc/disc_entropy                | 0.265    |
# |    disc/disc_loss                   | 0.247    |
# |    disc/disc_proportion_expert_pred | 0.58     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.903    |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.831    |
# |    disc/disc_entropy                | 0.261    |
# |    disc/disc_loss                   | 0.233    |
# |    disc/disc_proportion_expert_pred | 0.572    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.9      |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.825    |
# |    disc/disc_entropy                | 0.255    |
# |    disc/disc_loss                   | 0.223    |
# |    disc/disc_proportion_expert_pred | 0.575    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.908    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.837    |
# |    disc/disc_entropy                | 0.255    |
# |    disc/disc_loss                   | 0.212    |
# |    disc/disc_proportion_expert_pred | 0.571    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.912    |
# |    disc/disc_acc_expert             | 0.97     |
# |    disc/disc_acc_gen                | 0.854    |
# |    disc/disc_entropy                | 0.249    |
# |    disc/disc_loss                   | 0.199    |
# |    disc/disc_proportion_expert_pred | 0.558    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.916    |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.855    |
# |    disc/disc_entropy                | 0.242    |
# |    disc/disc_loss                   | 0.194    |
# |    disc/disc_proportion_expert_pred | 0.56     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.911    |
# |    disc/disc_acc_expert             | 0.985    |
# |    disc/disc_acc_gen                | 0.836    |
# |    disc/disc_entropy                | 0.247    |
# |    disc/disc_loss                   | 0.205    |
# |    disc/disc_proportion_expert_pred | 0.575    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.903    |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.83     |
# |    disc/disc_entropy                | 0.255    |
# |    disc/disc_loss                   | 0.223    |
# |    disc/disc_proportion_expert_pred | 0.573    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 5.96     |
# |    gen/rollout/ep_rew_mean          | -7.07    |
# |    gen/rollout/ep_rew_wrapped_mean  | 1.83     |
# |    gen/time/fps                     | 62       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 32       |
# |    gen/time/total_timesteps         | 9.63e+04 |
# |    gen/train/approx_kl              | 0.0962   |
# |    gen/train/clip_fraction          | 0.333    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -3.5     |
# |    gen/train/explained_variance     | 0.165    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.62     |
# |    gen/train/n_updates              | 235      |
# |    gen/train/policy_gradient_loss   | -0.0474  |
# |    gen/train/value_loss             | 1.2      |
# --------------------------------------------------
# round:  98%|█████████▊| 47/48 [31:52<00:42, 42.17s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 6           |
# |    gen/rollout/ep_rew_mean         | -7.61       |
# |    gen/rollout/ep_rew_wrapped_mean | 1.86        |
# |    gen/time/fps                    | 65          |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 31          |
# |    gen/time/total_timesteps        | 98304       |
# |    gen/train/approx_kl             | 0.096188486 |
# |    gen/train/clip_fraction         | 0.333       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -3.5        |
# |    gen/train/explained_variance    | 0.165       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.62        |
# |    gen/train/n_updates             | 235         |
# |    gen/train/policy_gradient_loss  | -0.0474     |
# |    gen/train/value_loss            | 1.2         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.893    |
# |    disc/disc_acc_expert             | 0.972    |
# |    disc/disc_acc_gen                | 0.814    |
# |    disc/disc_entropy                | 0.271    |
# |    disc/disc_loss                   | 0.238    |
# |    disc/disc_proportion_expert_pred | 0.579    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.897    |
# |    disc/disc_acc_expert             | 0.974    |
# |    disc/disc_acc_gen                | 0.821    |
# |    disc/disc_entropy                | 0.252    |
# |    disc/disc_loss                   | 0.236    |
# |    disc/disc_proportion_expert_pred | 0.576    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.892    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.806    |
# |    disc/disc_entropy                | 0.252    |
# |    disc/disc_loss                   | 0.229    |
# |    disc/disc_proportion_expert_pred | 0.586    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.901    |
# |    disc/disc_acc_expert             | 0.968    |
# |    disc/disc_acc_gen                | 0.835    |
# |    disc/disc_entropy                | 0.245    |
# |    disc/disc_loss                   | 0.219    |
# |    disc/disc_proportion_expert_pred | 0.566    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.912    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.845    |
# |    disc/disc_entropy                | 0.243    |
# |    disc/disc_loss                   | 0.202    |
# |    disc/disc_proportion_expert_pred | 0.567    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.913    |
# |    disc/disc_acc_expert             | 0.983    |
# |    disc/disc_acc_gen                | 0.843    |
# |    disc/disc_entropy                | 0.246    |
# |    disc/disc_loss                   | 0.2      |
# |    disc/disc_proportion_expert_pred | 0.57     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.908    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.837    |
# |    disc/disc_entropy                | 0.234    |
# |    disc/disc_loss                   | 0.197    |
# |    disc/disc_proportion_expert_pred | 0.571    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.909    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.84     |
# |    disc/disc_entropy                | 0.227    |
# |    disc/disc_loss                   | 0.193    |
# |    disc/disc_proportion_expert_pred | 0.569    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.903    |
# |    disc/disc_acc_expert             | 0.976    |
# |    disc/disc_acc_gen                | 0.83     |
# |    disc/disc_entropy                | 0.246    |
# |    disc/disc_loss                   | 0.214    |
# |    disc/disc_proportion_expert_pred | 0.573    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 6        |
# |    gen/rollout/ep_rew_mean          | -7.61    |
# |    gen/rollout/ep_rew_wrapped_mean  | 1.86     |
# |    gen/time/fps                     | 65       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 31       |
# |    gen/time/total_timesteps         | 9.83e+04 |
# |    gen/train/approx_kl              | 0.0481   |
# |    gen/train/clip_fraction          | 0.372    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -4.1     |
# |    gen/train/explained_variance     | 0.136    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.521    |
# |    gen/train/n_updates              | 240      |
# |    gen/train/policy_gradient_loss   | -0.051   |
# |    gen/train/value_loss             | 1.02     |
# --------------------------------------------------
# round: 100%|██████████| 48/48 [32:32<00:00, 40.68s/it]

# %%
print(
    "Rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)
print(
    "Rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# Rewards before training: -8.5 +/- 2.2561028345356955
# Rewards after training: -6.0 +/- 0.0
